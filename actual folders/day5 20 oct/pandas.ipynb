# %%
import pandas
# get the pandas library

# %%
import pandas as pd
# get the pandas library and name it as pd

# %%
dfa = pd.read_excel('research.xlsx')       # data frame

# %%
dfa
# Out:
#                                           Table                 Breakdown  \
# 0                      01 Total R&D Expenditure        01_R&D Expenditure
# 1                      01 Total R&D Expenditure        01_R&D Expenditure
# 2                      01 Total R&D Expenditure        01_R&D Expenditure
# 3                      01 Total R&D Expenditure        01_R&D Expenditure
# 4                      01 Total R&D Expenditure        01_R&D Expenditure
# ..                                          ...                       ...
# 895  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 896  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 897  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 898  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 899  15 Broad purpose of research by sub-sector  16_Total Business Sector
#
#           Secondary_Breakdown  Year Value        Unit
# ...

# %%
print(dfa )
# Out:
#                                           Table                 Breakdown  \
# 0                      01 Total R&D Expenditure        01_R&D Expenditure
# 1                      01 Total R&D Expenditure        01_R&D Expenditure
# 2                      01 Total R&D Expenditure        01_R&D Expenditure
# 3                      01 Total R&D Expenditure        01_R&D Expenditure
# 4                      01 Total R&D Expenditure        01_R&D Expenditure
# ..                                          ...                       ...
# 895  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 896  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 897  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 898  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 899  15 Broad purpose of research by sub-sector  16_Total Business Sector
#
#           Secondary_Breakdown  Year Value        Unit
# ...

# %%
dfb = pd.read_excel('electronic.xlsx')

# %%
dfb
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0           ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars
# 1           ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars
# 2           ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars
# 3           ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars
# 4           ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars
# ...                ...      ...         ...        ...    ...      ...
# 17236       ECTQ.S4AXP  2019.09        44.9        NaN      F  Percent
# 17237       ECTQ.S4AXP  2019.12        43.6        NaN      F  Percent
# 17238       ECTQ.S4AXP  2020.03        42.6        NaN      F  Percent
# 17239       ECTQ.S4AXP  2020.06        36.3        NaN      F  Percent
# 17240       ECTQ.S4AXP  2020.09        39.5        NaN      F  Percent
#
#        Magnitude                                        Subject  \
# ...

# %%
dfa.shape
# Out:
# (900, 6)

# %%
dfa.shape[0]   #rows
# Out:
# 900

# %%
dfa.columns
# Out:
# Index(['Table', 'Breakdown', 'Secondary_Breakdown', 'Year', 'Value', 'Unit'], dtype='object')

# %%
dfa
# Out:
#                                           Table                 Breakdown  \
# 0                      01 Total R&D Expenditure        01_R&D Expenditure
# 1                      01 Total R&D Expenditure        01_R&D Expenditure
# 2                      01 Total R&D Expenditure        01_R&D Expenditure
# 3                      01 Total R&D Expenditure        01_R&D Expenditure
# 4                      01 Total R&D Expenditure        01_R&D Expenditure
# ..                                          ...                       ...
# 895  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 896  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 897  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 898  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 899  15 Broad purpose of research by sub-sector  16_Total Business Sector
#
#           Secondary_Breakdown  Year Value        Unit
# ...

# %%
research_col = list(dfa.columns)

# %%
research_col
# Out:
# ['Table', 'Breakdown', 'Secondary_Breakdown', 'Year', 'Value', 'Unit']

# %%
dfa
# Out:
#                                           Table                 Breakdown  \
# 0                      01 Total R&D Expenditure        01_R&D Expenditure
# 1                      01 Total R&D Expenditure        01_R&D Expenditure
# 2                      01 Total R&D Expenditure        01_R&D Expenditure
# 3                      01 Total R&D Expenditure        01_R&D Expenditure
# 4                      01 Total R&D Expenditure        01_R&D Expenditure
# ..                                          ...                       ...
# 895  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 896  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 897  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 898  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 899  15 Broad purpose of research by sub-sector  16_Total Business Sector
#
#           Secondary_Breakdown  Year Value        Unit
# ...

# %%
dfa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Table                900 non-null    object
#  1   Breakdown            900 non-null    object
#  2   Secondary_Breakdown  900 non-null    object
#  3   Year                 900 non-null    int64
#  4   Value                900 non-null    object
#  5   Unit                 900 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 42.3+ KB

# %%
dfb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17241 entries, 0 to 17240
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Series_reference  17241 non-null  object
#  1   Period            17241 non-null  float64
#  2   Data_value        16003 non-null  float64
#  3   Suppressed        117 non-null    object
#  4   STATUS            17241 non-null  object
#  5   UNITS             17241 non-null  object
#  6   Magnitude         17241 non-null  int64
#  7   Subject           17241 non-null  object
#  8   Group             17241 non-null  object
#  9   Series_title_1    17241 non-null  object
#  10  Series_title_2    17241 non-null  object
#  11  Series_title_3    3409 non-null   object
#  12  Series_title_4    0 non-null      float64
#  13  Series_title_5    0 non-null      float64
# dtypes: float64(4), int64(1), object(9)
# memory usage: 1.8+ MB

# %%
dfb.shape
# Out:
# (17241, 14)

# %%
dfb.describe()
# Out:
#              Period    Data_value     Magnitude  Series_title_4  \
# count  17241.000000  1.600300e+04  17241.000000             0.0
# mean    2010.634210  1.480186e+07      4.201148             NaN
# std        5.619966  8.206415e+07      2.749124             NaN
# min     2000.010000 -5.130000e+01      0.000000             NaN
# 25%     2006.050000  1.766500e+02      0.000000             NaN
# 50%     2011.010000  1.150200e+03      6.000000             NaN
# 75%     2015.120000  4.078650e+03      6.000000             NaN
# max     2020.090000  1.874441e+09      6.000000             NaN
#
#        Series_title_5
# count             0.0
# mean              NaN
# std               NaN
# min               NaN
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max               NaN

# %%
dfa.describe()
# Out:
#               Year
# count   900.000000
# mean   2015.800000
# std       2.562674
# min    2012.000000
# 25%    2014.000000
# 50%    2016.000000
# 75%    2018.000000
# max    2019.000000

# %%
help(dfa.describe)
# Out:
# Help on method describe in module pandas.core.generic:
#
# describe(percentiles=None, include=None, exclude=None, datetime_is_numeric=False) -> ~FrameOrSeries method of pandas.core.frame.DataFrame instance
#     Generate descriptive statistics.
#
#     Descriptive statistics include those that summarize the central
#     tendency, dispersion and shape of a
#     dataset's distribution, excluding ``NaN`` values.
#
#     Analyzes both numeric and object series, as well
#     as ``DataFrame`` column sets of mixed data types. The output
#     will vary depending on what is provided. Refer to the notes
#     below for more detail.
#
#     Parameters
#     ----------
#     percentiles : list-like of numbers, optional
#         The percentiles to include in the output. All should
#         fall between 0 and 1. The default is
#         ``[.25, .5, .75]``, which returns the 25th, 50th, and
#         75th percentiles.
#     include : 'all', list-like of dtypes or None (default), optional
# ...

# %%
dfa
# Out:
#                                           Table                 Breakdown  \
# 0                      01 Total R&D Expenditure        01_R&D Expenditure
# 1                      01 Total R&D Expenditure        01_R&D Expenditure
# 2                      01 Total R&D Expenditure        01_R&D Expenditure
# 3                      01 Total R&D Expenditure        01_R&D Expenditure
# 4                      01 Total R&D Expenditure        01_R&D Expenditure
# ..                                          ...                       ...
# 895  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 896  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 897  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 898  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 899  15 Broad purpose of research by sub-sector  16_Total Business Sector
#
#           Secondary_Breakdown  Year Value        Unit
# ...

# %%
dfa['Table'].nunique()
# Out:
# 15

# %%
dfa['Table'].unique()
# Out:
# array(['01 Total R&D Expenditure',
#        '02 Total R&D Expenditure by published industry',
#        '03 Businesses performing R&D by published industry',
#        '04 Total R&D Expenditure by ANZSIC industry',
#        '05 Purpose of Research', '06 Source of funds',
#        '07 Type of Research', '08 Type of expenditure',
#        '09 Expectation of future levels of R&D by sub-sect',
#        '10 Reason for carrying out or funding R&D by sub-s',
#        '11 Full-Time equivalent personnel by occupation',
#        '11 Headcount of personnel by occupation',
#        '12 Total R&D Expenditure by size',
#        '13 Businesses performing R&D by size',
#        '15 Broad purpose of research by sub-sector'], dtype=object)

# %%
dfa['Table'].value_counts()
# Out:
# 09 Expectation of future levels of R&D by sub-sect    100
# 10 Reason for carrying out or funding R&D by sub-s    100
# 15 Broad purpose of research by sub-sector            100
# 04 Total R&D Expenditure by ANZSIC industry            80
# 02 Total R&D Expenditure by published industry         80
# 08 Type of expenditure                                 80
# 03 Businesses performing R&D by published industry     80
# 05 Purpose of Research                                 70
# 06 Source of funds                                     40
# 01 Total R&D Expenditure                               40
# 12 Total R&D Expenditure by size                       35
# 13 Businesses performing R&D by size                   35
# 07 Type of Research                                    20
# 11 Full-Time equivalent personnel by occupation        20
# 11 Headcount of personnel by occupation                20
# Name: Table, dtype: int64

# %%
dfa['Year'].value_counts()
# Out:
# 2019    180
# 2018    180
# 2016    180
# 2014    180
# 2012    180
# Name: Year, dtype: int64

# %%
dfa['Unit'].value_counts()
# Out:
# $(million)    545
# Percent       200
# Count         155
# Name: Unit, dtype: int64

# %%
dfb
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0           ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars
# 1           ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars
# 2           ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars
# 3           ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars
# 4           ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars
# ...                ...      ...         ...        ...    ...      ...
# 17236       ECTQ.S4AXP  2019.09        44.9        NaN      F  Percent
# 17237       ECTQ.S4AXP  2019.12        43.6        NaN      F  Percent
# 17238       ECTQ.S4AXP  2020.03        42.6        NaN      F  Percent
# 17239       ECTQ.S4AXP  2020.06        36.3        NaN      F  Percent
# 17240       ECTQ.S4AXP  2020.09        39.5        NaN      F  Percent
#
#        Magnitude                                        Subject  \
# ...

# %%
#  NaN  
#  nan or null = missing values

# %%
dfa.isna().sum()
# Out:
# Table                  0
# Breakdown              0
# Secondary_Breakdown    0
# Year                   0
# Value                  0
# Unit                   0
# dtype: int64

# %%
dfb.isna().sum()
# Out:
# Series_reference        0
# Period                  0
# Data_value           1238
# Suppressed          17124
# STATUS                  0
# UNITS                   0
# Magnitude               0
# Subject                 0
# Group                   0
# Series_title_1          0
# Series_title_2          0
# Series_title_3      13832
# Series_title_4      17241
# Series_title_5      17241
# dtype: int64

# %%
dfb.isnull().sum()
# Out:
# Series_reference        0
# Period                  0
# Data_value           1238
# Suppressed          17124
# STATUS                  0
# UNITS                   0
# Magnitude               0
# Subject                 0
# Group                   0
# Series_title_1          0
# Series_title_2          0
# Series_title_3      13832
# Series_title_4      17241
# Series_title_5      17241
# dtype: int64

# %%
del dfb['Series_title_4']

# %%
dfb
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0           ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars
# 1           ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars
# 2           ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars
# 3           ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars
# 4           ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars
# ...                ...      ...         ...        ...    ...      ...
# 17236       ECTQ.S4AXP  2019.09        44.9        NaN      F  Percent
# 17237       ECTQ.S4AXP  2019.12        43.6        NaN      F  Percent
# 17238       ECTQ.S4AXP  2020.03        42.6        NaN      F  Percent
# 17239       ECTQ.S4AXP  2020.06        36.3        NaN      F  Percent
# 17240       ECTQ.S4AXP  2020.09        39.5        NaN      F  Percent
#
#        Magnitude                                        Subject  \
# ...

# %%
dfb = pd.read_excel('electronic.xlsx')

# %%
dfb.drop(['Series_title_4', 'Series_title_5'], axis=1) # axis = 1 means columns
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0           ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars
# 1           ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars
# 2           ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars
# 3           ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars
# 4           ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars
# ...                ...      ...         ...        ...    ...      ...
# 17236       ECTQ.S4AXP  2019.09        44.9        NaN      F  Percent
# 17237       ECTQ.S4AXP  2019.12        43.6        NaN      F  Percent
# 17238       ECTQ.S4AXP  2020.03        42.6        NaN      F  Percent
# 17239       ECTQ.S4AXP  2020.06        36.3        NaN      F  Percent
# 17240       ECTQ.S4AXP  2020.09        39.5        NaN      F  Percent
#
#        Magnitude                                        Subject  \
# ...

# %%
dfb
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0           ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars
# 1           ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars
# 2           ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars
# 3           ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars
# 4           ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars
# ...                ...      ...         ...        ...    ...      ...
# 17236       ECTQ.S4AXP  2019.09        44.9        NaN      F  Percent
# 17237       ECTQ.S4AXP  2019.12        43.6        NaN      F  Percent
# 17238       ECTQ.S4AXP  2020.03        42.6        NaN      F  Percent
# 17239       ECTQ.S4AXP  2020.06        36.3        NaN      F  Percent
# 17240       ECTQ.S4AXP  2020.09        39.5        NaN      F  Percent
#
#        Magnitude                                        Subject  \
# ...

# %%
dfb.drop(['Series_title_4', 'Series_title_5'], axis=1)

#dfb = dfb.drop(['Series_title_4', 'Series_title_5'], axis=1)

dfb.drop(['Series_title_4', 'Series_title_5'], axis=1, inplace=True)
# inplace = in the data frame 
# delete in the data frame

# %%
dfb
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0           ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars
# 1           ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars
# 2           ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars
# 3           ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars
# 4           ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars
# ...                ...      ...         ...        ...    ...      ...
# 17236       ECTQ.S4AXP  2019.09        44.9        NaN      F  Percent
# 17237       ECTQ.S4AXP  2019.12        43.6        NaN      F  Percent
# 17238       ECTQ.S4AXP  2020.03        42.6        NaN      F  Percent
# 17239       ECTQ.S4AXP  2020.06        36.3        NaN      F  Percent
# 17240       ECTQ.S4AXP  2020.09        39.5        NaN      F  Percent
#
#        Magnitude                                        Subject  \
# ...

# %%
dfb.isnull().sum()
# Out:
# Series_reference        0
# Period                  0
# Data_value           1238
# Suppressed          17124
# STATUS                  0
# UNITS                   0
# Magnitude               0
# Subject                 0
# Group                   0
# Series_title_1          0
# Series_title_2          0
# Series_title_3      13832
# dtype: int64

# %%
dfb['UNITS'].value_counts()
# Out:
# Dollars    12528
# Percent     2850
# Number      1863
# Name: UNITS, dtype: int64

# %%
# filter dfb['UNITS'] == 'Number'

dfb[ dfb['UNITS']=='Number' ]
# Out:
#       Series_reference   Period   Data_value Suppressed STATUS   UNITS  \
# 260         ECTA.S29A1  2001.03          NaN        NaN      C  Number
# 261         ECTA.S29A1  2002.03          NaN        NaN      C  Number
# 262         ECTA.S29A1  2003.03          NaN        NaN      C  Number
# 263         ECTA.S29A1  2004.03  588806931.0        NaN      F  Number
# 264         ECTA.S29A1  2005.03  646646117.0        NaN      F  Number
# ...                ...      ...          ...        ...    ...     ...
# 16906       ECTQ.S4A3N  2019.06         89.5        NaN      R  Number
# 16907       ECTQ.S4A3N  2019.09         92.5        NaN      P  Number
# 16908       ECTQ.S4A3N  2019.12         99.7        NaN      P  Number
# 16909       ECTQ.S4A3N  2020.03         90.0        NaN      P  Number
# 16910       ECTQ.S4A3N  2020.06         61.1        NaN      P  Number
#
#        Magnitude                                        Subject  \
# ...

# %%
# dfb = dfb[ dfb['UNITS']=='Number' ]

dfc = dfb[ dfb['UNITS']=='Number' ]

# %%
#   dfc is a new data frame
#       is a subset of dfb

# %%
dfc.to_excel('sir hegazy.xlsx', index=None)

# %%
dfc.to_excel('sir hegazy.xlsx')

# %%
dfb
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0           ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars
# 1           ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars
# 2           ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars
# 3           ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars
# 4           ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars
# ...                ...      ...         ...        ...    ...      ...
# 17236       ECTQ.S4AXP  2019.09        44.9        NaN      F  Percent
# 17237       ECTQ.S4AXP  2019.12        43.6        NaN      F  Percent
# 17238       ECTQ.S4AXP  2020.03        42.6        NaN      F  Percent
# 17239       ECTQ.S4AXP  2020.06        36.3        NaN      F  Percent
# 17240       ECTQ.S4AXP  2020.09        39.5        NaN      F  Percent
#
#        Magnitude                                        Subject  \
# ...

# %%
# sorting
# cumulative sum
# new column

# %%
dfb['sold'] = 'yes'

# %%
dfb
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0           ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars
# 1           ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars
# 2           ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars
# 3           ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars
# 4           ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars
# ...                ...      ...         ...        ...    ...      ...
# 17236       ECTQ.S4AXP  2019.09        44.9        NaN      F  Percent
# 17237       ECTQ.S4AXP  2019.12        43.6        NaN      F  Percent
# 17238       ECTQ.S4AXP  2020.03        42.6        NaN      F  Percent
# 17239       ECTQ.S4AXP  2020.06        36.3        NaN      F  Percent
# 17240       ECTQ.S4AXP  2020.09        39.5        NaN      F  Percent
#
#        Magnitude                                        Subject  \
# ...

# %%
dfb.dtypes
# Out:
# Series_reference     object
# Period              float64
# Data_value          float64
# Suppressed           object
# STATUS               object
# UNITS                object
# Magnitude             int64
# Subject              object
# Group                object
# Series_title_1       object
# Series_title_2       object
# Series_title_3       object
# sold                 object
# dtype: object

# %%
dfb['sold'] = 1

# %%
dfb.dtypes
# Out:
# Series_reference     object
# Period              float64
# Data_value          float64
# Suppressed           object
# STATUS               object
# UNITS                object
# Magnitude             int64
# Subject              object
# Group                object
# Series_title_1       object
# Series_title_2       object
# Series_title_3       object
# sold                  int64
# dtype: object

# %%
dfd = dfb[0:10]

# %%
dfd
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0       ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars          6
# 1       ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars          6
# 2       ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars          6
# 3       ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars          6
# 4       ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars          6
# 5       ECTA.S19A1  2006.03     33317.4        NaN      F  Dollars          6
# 6       ECTA.S19A1  2007.03     36422.0        NaN      F  Dollars          6
# 7       ECTA.S19A1  2008.03     39198.0        NaN      F  Dollars          6
# 8       ECTA.S19A1  2009.03     40629.4        NaN      F  Dollars          6
# 9       ECTA.S19A1  2010.03     41815.4        NaN      F  Dollars          6
#
#                                          Subject  \
# 0  Electronic Card Transactions (ANZSIC06) - ECT
# ...

# %%
dfd
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0       ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars          6
# 1       ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars          6
# 2       ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars          6
# 3       ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars          6
# 4       ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars          6
# 5       ECTA.S19A1  2006.03     33317.4        NaN      F  Dollars          6
# 6       ECTA.S19A1  2007.03     36422.0        NaN      F  Dollars          6
# 7       ECTA.S19A1  2008.03     39198.0        NaN      F  Dollars          6
# 8       ECTA.S19A1  2009.03     40629.4        NaN      F  Dollars          6
# 9       ECTA.S19A1  2010.03     41815.4        NaN      F  Dollars          6
#
#                                          Subject  \
# 0  Electronic Card Transactions (ANZSIC06) - ECT
# ...

# %%
dfd = dfb[0:10]

dfd['sold'] = ['y', 'y', 'n', 'n', 'y', 'y', 'y', 'y', 'n', 'n']
# Out:
# /Users/shobhit/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
dfd
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0       ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars          6
# 1       ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars          6
# 2       ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars          6
# 3       ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars          6
# 4       ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars          6
# 5       ECTA.S19A1  2006.03     33317.4        NaN      F  Dollars          6
# 6       ECTA.S19A1  2007.03     36422.0        NaN      F  Dollars          6
# 7       ECTA.S19A1  2008.03     39198.0        NaN      F  Dollars          6
# 8       ECTA.S19A1  2009.03     40629.4        NaN      F  Dollars          6
# 9       ECTA.S19A1  2010.03     41815.4        NaN      F  Dollars          6
#
#                                          Subject  \
# 0  Electronic Card Transactions (ANZSIC06) - ECT
# ...

# %%
dfd.assign(location = ['asia', 'eu', 'na', 'asia', 'eu', 'na', 'asia', 'eu', 'na', 'na'])
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0       ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars          6
# 1       ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars          6
# 2       ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars          6
# 3       ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars          6
# 4       ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars          6
# 5       ECTA.S19A1  2006.03     33317.4        NaN      F  Dollars          6
# 6       ECTA.S19A1  2007.03     36422.0        NaN      F  Dollars          6
# 7       ECTA.S19A1  2008.03     39198.0        NaN      F  Dollars          6
# 8       ECTA.S19A1  2009.03     40629.4        NaN      F  Dollars          6
# 9       ECTA.S19A1  2010.03     41815.4        NaN      F  Dollars          6
#
#                                          Subject  \
# 0  Electronic Card Transactions (ANZSIC06) - ECT
# ...

# %%
dfd = dfd.assign(location = ['asia', 'eu', 'na', 'asia', 'eu', 'na', 'asia', 'eu', 'na', 'na'])

# %%
dfd
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0       ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars          6
# 1       ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars          6
# 2       ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars          6
# 3       ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars          6
# 4       ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars          6
# 5       ECTA.S19A1  2006.03     33317.4        NaN      F  Dollars          6
# 6       ECTA.S19A1  2007.03     36422.0        NaN      F  Dollars          6
# 7       ECTA.S19A1  2008.03     39198.0        NaN      F  Dollars          6
# 8       ECTA.S19A1  2009.03     40629.4        NaN      F  Dollars          6
# 9       ECTA.S19A1  2010.03     41815.4        NaN      F  Dollars          6
#
#                                          Subject  \
# 0  Electronic Card Transactions (ANZSIC06) - ECT
# ...

# %%
help(dfd.assign)
# Out:
# Help on method assign in module pandas.core.frame:
#
# assign(**kwargs) -> 'DataFrame' method of pandas.core.frame.DataFrame instance
#     Assign new columns to a DataFrame.
#
#     Returns a new object with all original columns in addition to new ones.
#     Existing columns that are re-assigned will be overwritten.
#
#     Parameters
#     ----------
#     **kwargs : dict of {str: callable or Series}
#         The column names are keywords. If the values are
#         callable, they are computed on the DataFrame and
#         assigned to the new columns. The callable must not
#         change input DataFrame (though pandas doesn't check it).
#         If the values are not callable, (e.g. a Series, scalar, or array),
#         they are simply assigned.
#
#     Returns
#     -------
#     DataFrame
#         A new DataFrame with the new columns in addition to
#         all the existing columns.
#
#     Notes
#     -----
# ...

# %%
dfd
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0       ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars          6
# 1       ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars          6
# 2       ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars          6
# 3       ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars          6
# 4       ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars          6
# 5       ECTA.S19A1  2006.03     33317.4        NaN      F  Dollars          6
# 6       ECTA.S19A1  2007.03     36422.0        NaN      F  Dollars          6
# 7       ECTA.S19A1  2008.03     39198.0        NaN      F  Dollars          6
# 8       ECTA.S19A1  2009.03     40629.4        NaN      F  Dollars          6
# 9       ECTA.S19A1  2010.03     41815.4        NaN      F  Dollars          6
#
#                                          Subject  \
# 0  Electronic Card Transactions (ANZSIC06) - ECT
# ...

# %%
dfd.sort_values('Data_value')
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0       ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars          6
# 1       ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars          6
# 2       ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars          6
# 3       ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars          6
# 4       ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars          6
# 5       ECTA.S19A1  2006.03     33317.4        NaN      F  Dollars          6
# 6       ECTA.S19A1  2007.03     36422.0        NaN      F  Dollars          6
# 7       ECTA.S19A1  2008.03     39198.0        NaN      F  Dollars          6
# 8       ECTA.S19A1  2009.03     40629.4        NaN      F  Dollars          6
# 9       ECTA.S19A1  2010.03     41815.4        NaN      F  Dollars          6
#
#                                          Subject  \
# 0  Electronic Card Transactions (ANZSIC06) - ECT
# ...

# %%
dfd.sort_values('Data_value', ascending=False)
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 9       ECTA.S19A1  2010.03     41815.4        NaN      F  Dollars          6
# 8       ECTA.S19A1  2009.03     40629.4        NaN      F  Dollars          6
# 7       ECTA.S19A1  2008.03     39198.0        NaN      F  Dollars          6
# 6       ECTA.S19A1  2007.03     36422.0        NaN      F  Dollars          6
# 5       ECTA.S19A1  2006.03     33317.4        NaN      F  Dollars          6
# 4       ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars          6
# 3       ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars          6
# 2       ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars          6
# 1       ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars          6
# 0       ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars          6
#
#                                          Subject  \
# 9  Electronic Card Transactions (ANZSIC06) - ECT
# ...

# %%
dfd
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0       ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars          6
# 1       ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars          6
# 2       ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars          6
# 3       ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars          6
# 4       ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars          6
# 5       ECTA.S19A1  2006.03     33317.4        NaN      F  Dollars          6
# 6       ECTA.S19A1  2007.03     36422.0        NaN      F  Dollars          6
# 7       ECTA.S19A1  2008.03     39198.0        NaN      F  Dollars          6
# 8       ECTA.S19A1  2009.03     40629.4        NaN      F  Dollars          6
# 9       ECTA.S19A1  2010.03     41815.4        NaN      F  Dollars          6
#
#                                          Subject  \
# 0  Electronic Card Transactions (ANZSIC06) - ECT
# ...

# %%
dfa
# Out:
#                                           Table                 Breakdown  \
# 0                      01 Total R&D Expenditure        01_R&D Expenditure
# 1                      01 Total R&D Expenditure        01_R&D Expenditure
# 2                      01 Total R&D Expenditure        01_R&D Expenditure
# 3                      01 Total R&D Expenditure        01_R&D Expenditure
# 4                      01 Total R&D Expenditure        01_R&D Expenditure
# ..                                          ...                       ...
# 895  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 896  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 897  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 898  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 899  15 Broad purpose of research by sub-sector  16_Total Business Sector
#
#           Secondary_Breakdown  Year Value        Unit
# ...

# %%
dfd
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0       ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars          6
# 1       ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars          6
# 2       ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars          6
# 3       ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars          6
# 4       ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars          6
# 5       ECTA.S19A1  2006.03     33317.4        NaN      F  Dollars          6
# 6       ECTA.S19A1  2007.03     36422.0        NaN      F  Dollars          6
# 7       ECTA.S19A1  2008.03     39198.0        NaN      F  Dollars          6
# 8       ECTA.S19A1  2009.03     40629.4        NaN      F  Dollars          6
# 9       ECTA.S19A1  2010.03     41815.4        NaN      F  Dollars          6
#
#                                          Subject  \
# 0  Electronic Card Transactions (ANZSIC06) - ECT
# ...

# %%
dfd['cum_data_val'] = dfd['Data_value'].cumsum()

# %%
dfd
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0       ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars          6
# 1       ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars          6
# 2       ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars          6
# 3       ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars          6
# 4       ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars          6
# 5       ECTA.S19A1  2006.03     33317.4        NaN      F  Dollars          6
# 6       ECTA.S19A1  2007.03     36422.0        NaN      F  Dollars          6
# 7       ECTA.S19A1  2008.03     39198.0        NaN      F  Dollars          6
# 8       ECTA.S19A1  2009.03     40629.4        NaN      F  Dollars          6
# 9       ECTA.S19A1  2010.03     41815.4        NaN      F  Dollars          6
#
#                                          Subject  \
# 0  Electronic Card Transactions (ANZSIC06) - ECT
# ...

# %%
dfa
# Out:
#                                           Table                 Breakdown  \
# 0                      01 Total R&D Expenditure        01_R&D Expenditure
# 1                      01 Total R&D Expenditure        01_R&D Expenditure
# 2                      01 Total R&D Expenditure        01_R&D Expenditure
# 3                      01 Total R&D Expenditure        01_R&D Expenditure
# 4                      01 Total R&D Expenditure        01_R&D Expenditure
# ..                                          ...                       ...
# 895  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 896  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 897  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 898  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 899  15 Broad purpose of research by sub-sector  16_Total Business Sector
#
#           Secondary_Breakdown  Year Value        Unit
# ...

# %%
dfe = dfa

dfe = dfa.copy()

# %%
dfe = dfe.sort_values('Year')
dfe['cum'] = dfe['Year'].cumsum()

dfe.to_excel('four.xlsx', index=None)

# %%
dfe = dfa.copy()

dfe['cum'] = dfe.sort_values('Year')['Year'].cumsum()

dfe.to_excel('five.xlsx', index=None)

# %%
dfe.sort_values('Year')
# Out:
#                                            Table  \
# 0                       01 Total R&D Expenditure
# 255  04 Total R&D Expenditure by ANZSIC industry
# 260  04 Total R&D Expenditure by ANZSIC industry
# 845   15 Broad purpose of research by sub-sector
# 265  04 Total R&D Expenditure by ANZSIC industry
# ..                                           ...
# 489                       08 Type of expenditure
# 484                       08 Type of expenditure
# 479                       08 Type of expenditure
# 469                       08 Type of expenditure
# 899   15 Broad purpose of research by sub-sector
#
#                                 Breakdown       Secondary_Breakdown  Year  \
# 0                      01_R&D Expenditure               1) Business  2012
# 255   12_Public Administration and Safety                      None  2012
# 260  13_Health Care and Social Assistance                      None  2012
# 845                            03_Society          02_Manufacturing  2012
# ...

# %%
dfe = dfa.copy()

dfe['cum'] = dfe.sort_values('Year')['Year'].cumsum()

dfe = dfe.sort_values('cum')

dfe.to_excel('six.xlsx', index=None)

# %%
city = {'us': ['washington DC', 'new york'], 
               'germany': ['BERLIN', 'munich'], 
               'indonesia': ['jakarta', 'java'], 
               'india': ['new delhi', 'mumbai']
               }

# %%
city
# Out:
# {'us': ['washington DC', 'new york'],
#  'germany': ['BERLIN', 'munich'],
#  'indonesia': ['jakarta', 'java'],
#  'india': ['new delhi', 'mumbai']}

# %%
dff = pd.DataFrame(city)

# %%
dff
# Out:
#               us germany indonesia      india
# 0  washington DC  BERLIN   jakarta  new delhi
# 1       new york  munich      java     mumbai

# %%
dff.T     #transpose
# Out:
#                        0         1
# us         washington DC  new york
# germany           BERLIN    munich
# indonesia        jakarta      java
# india          new delhi    mumbai

# %%
dff = pd.DataFrame(city)

# %%
dff
# Out:
#               us germany indonesia      india
# 0  washington DC  BERLIN   jakarta  new delhi
# 1       new york  munich      java     mumbai

# %%
dff = dff.T

# %%
dfb.describe()
# Out:
#              Period    Data_value     Magnitude     sold
# count  17241.000000  1.600300e+04  17241.000000  17241.0
# mean    2010.634210  1.480186e+07      4.201148      1.0
# std        5.619966  8.206415e+07      2.749124      0.0
# min     2000.010000 -5.130000e+01      0.000000      1.0
# 25%     2006.050000  1.766500e+02      0.000000      1.0
# 50%     2011.010000  1.150200e+03      6.000000      1.0
# 75%     2015.120000  4.078650e+03      6.000000      1.0
# max     2020.090000  1.874441e+09      6.000000      1.0

# %%
dfb.describe().T
# Out:
#               count          mean           std      min      25%      50%  \
# Period      17241.0  2.010634e+03  5.619966e+00  2000.01  2006.05  2011.01
# Data_value  16003.0  1.480186e+07  8.206415e+07   -51.30   176.65  1150.20
# Magnitude   17241.0  4.201148e+00  2.749124e+00     0.00     0.00     6.00
# sold        17241.0  1.000000e+00  0.000000e+00     1.00     1.00     1.00
#
#                 75%           max
# Period      2015.12  2.020090e+03
# Data_value  4078.65  1.874441e+09
# Magnitude      6.00  6.000000e+00
# sold           1.00  1.000000e+00

# %%
import pandas

dfx = pandas.read_excel('research.xlsx')

# %%
print(type(dfb))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# pd.DataFrame()     # dict

# pd.read_XXXX()     # external source
